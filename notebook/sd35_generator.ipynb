# %% [markdown]
# # SD3.5 Batch Image Generation

# %%
# Install packages
# !pip -q install -U diffusers transformers accelerate sentencepiece safetensors huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 93.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.6/642.6 kB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 116.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
from huggingface_hub import login
import getpass

token = userdata.get("HF_TOKEN")

if not token:
    token = getpass.getpass("Enter your Hugging Face token: ")

login(token=token)

# %%
# Set paths and generation settings
MODEL_ID = "stabilityai/stable-diffusion-3.5-medium"
PROJECT_ROOT = "YOUR_PROJECT_ROOT"
# CSV_PATH = f"{PROJECT_ROOT}/finetune_prompts/van_gogh_speculative_finetune_prompts-150.csv"
CSV_PATH = f"{PROJECT_ROOT}/finetune_prompts/van_gogh_speculative_finetune_prompts-300.csv"
# OUTPUT_DIR = f"{PROJECT_ROOT}/sd35_outputs-150"
OUTPUT_DIR = f"{PROJECT_ROOT}/sd35_outputs-300"

WIDTH = 1024
HEIGHT = 1024
GUIDANCE_SCALE = 7.0
NUM_INFERENCE_STEPS = 28
BASE_SEED = 42

# %%
# Load the CSV
import pandas as pd

required_cols = ["concept_rank", "concept_name", "prompt_id", "prompt"]

df = pd.read_csv(CSV_PATH)
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError(f"Missing columns: {missing}")

df = df[required_cols].copy()
df.head()
# Out:
#    concept_rank                                    concept_name  prompt_id  \
# 0             1  Star-swept night skies and cypress silhouettes          1
# 1             1  Star-swept night skies and cypress silhouettes          2
# 2             1  Star-swept night skies and cypress silhouettes          3
# 3             1  Star-swept night skies and cypress silhouettes          4
# 4             1  Star-swept night skies and cypress silhouettes          5
#
#                                               prompt
# 0  A tall cypress rising beside a moonlit village...
# 1  Three dark cypress trees leaning over a hillsi...
# 2  A small chapel tower beneath curling constella...
# 3  Rooftops clustered in a basin of blue hills wi...
# 4  A winding lane descending toward lit windows u...

# %%
# Load the model
import torch
from diffusers import StableDiffusion3Pipeline

print(torch.cuda.is_available())

dtype = torch.float16 if torch.cuda.is_available() else torch.float32

pipe = StableDiffusion3Pipeline.from_pretrained(MODEL_ID, torch_dtype=dtype)
pipe.set_progress_bar_config(disable=True)


if torch.cuda.is_available():
    pipe.enable_model_cpu_offload()
else:
    pipe.to("cpu")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# True
# model_index.json:   0%|          | 0.00/706 [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 26 files:   0%|          | 0/26 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/9 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/517 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/219 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]

# %%
# Generate and save images
import re
from pathlib import Path

out_dir = Path(OUTPUT_DIR)
out_dir.mkdir(parents=True, exist_ok=True)

def slugify(value):
    value = re.sub(r"[^a-zA-Z0-9_-]+", "_", str(value).strip())
    value = value.strip("_")
    return value[:80] or "item"

records = []

device = "cuda" if torch.cuda.is_available() else "cpu"

for i, row in df.iterrows():
    concept_rank = int(row["concept_rank"])
    concept_name = str(row["concept_name"])
    prompt_id = str(row["prompt_id"])
    prompt = str(row["prompt"])

    filename = f"{concept_rank:02d}_{slugify(concept_name)}_{slugify(prompt_id)}.png"
    image_path = out_dir / filename

    generator = torch.Generator(device=device).manual_seed(BASE_SEED + i)

    image = pipe(
        prompt=prompt,
        width=WIDTH,
        height=HEIGHT,
        guidance_scale=GUIDANCE_SCALE,
        num_inference_steps=NUM_INFERENCE_STEPS,
        generator=generator,
    ).images[0]

    image.save(image_path)
    records.append(
        {
            "concept_rank": concept_rank,
            "concept_name": concept_name,
            "prompt_id": prompt_id,
            "prompt": prompt,
            "image_path": str(image_path),
        }
    )
    print(f"[{i + 1}/{len(df)}] {image_path.name}")
# Out:
# [1/300] 01_Star-swept_night_skies_and_cypress_silhouettes_1.png
# [2/300] 01_Star-swept_night_skies_and_cypress_silhouettes_2.png
# [3/300] 01_Star-swept_night_skies_and_cypress_silhouettes_3.png
# [4/300] 01_Star-swept_night_skies_and_cypress_silhouettes_4.png
# [5/300] 01_Star-swept_night_skies_and_cypress_silhouettes_5.png
# [6/300] 01_Star-swept_night_skies_and_cypress_silhouettes_6.png
# [7/300] 01_Star-swept_night_skies_and_cypress_silhouettes_7.png
# [8/300] 01_Star-swept_night_skies_and_cypress_silhouettes_8.png
# [9/300] 01_Star-swept_night_skies_and_cypress_silhouettes_9.png
# [10/300] 01_Star-swept_night_skies_and_cypress_silhouettes_10.png
# [11/300] 01_Star-swept_night_skies_and_cypress_silhouettes_11.png
# [12/300] 01_Star-swept_night_skies_and_cypress_silhouettes_12.png
# [13/300] 01_Star-swept_night_skies_and_cypress_silhouettes_13.png
# [14/300] 01_Star-swept_night_skies_and_cypress_silhouettes_14.png
# [15/300] 01_Star-swept_night_skies_and_cypress_silhouettes_15.png
# [16/300] 01_Star-swept_night_skies_and_cypress_silhouettes_16.png
# [17/300] 01_Star-swept_night_skies_and_cypress_silhouettes_17.png
# [18/300] 01_Star-swept_night_skies_and_cypress_silhouettes_18.png
# [19/300] 01_Star-swept_night_skies_and_cypress_silhouettes_19.png
# [20/300] 01_Star-swept_night_skies_and_cypress_silhouettes_20.png
# [21/300] 01_Star-swept_night_skies_and_cypress_silhouettes_21.png
# [22/300] 01_Star-swept_night_skies_and_cypress_silhouettes_22.png
# [23/300] 01_Star-swept_night_skies_and_cypress_silhouettes_23.png
# [24/300] 01_Star-swept_night_skies_and_cypress_silhouettes_24.png
# [25/300] 01_Star-swept_night_skies_and_cypress_silhouettes_25.png
# [26/300] 01_Star-swept_night_skies_and_cypress_silhouettes_26.png
# [27/300] 01_Star-swept_night_skies_and_cypress_silhouettes_27.png
# [28/300] 01_Star-swept_night_skies_and_cypress_silhouettes_28.png
# [29/300] 01_Star-swept_night_skies_and_cypress_silhouettes_29.png
# [30/300] 01_Star-swept_night_skies_and_cypress_silhouettes_30.png
# [31/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_1.png
# [32/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_2.png
# [33/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_3.png
# [34/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_4.png
# [35/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_5.png
# [36/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_6.png
# [37/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_7.png
# [38/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_8.png
# [39/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_9.png
# [40/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_10.png
# [41/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_11.png
# [42/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_12.png
# [43/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_13.png
# [44/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_14.png
# [45/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_15.png
# [46/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_16.png
# [47/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_17.png
# [48/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_18.png
# [49/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_19.png
# [50/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_20.png
# [51/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_21.png
# [52/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_22.png
# [53/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_23.png
# [54/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_24.png
# [55/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_25.png
# [56/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_26.png
# [57/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_27.png
# [58/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_28.png
# [59/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_29.png
# [60/300] 02_Sunflower_still_lifes_and_yellow_garden_blooms_30.png
# [61/300] 03_Wheat_fields_furrows_and_restless_wind_1.png
# [62/300] 03_Wheat_fields_furrows_and_restless_wind_2.png
# [63/300] 03_Wheat_fields_furrows_and_restless_wind_3.png
# [64/300] 03_Wheat_fields_furrows_and_restless_wind_4.png
# [65/300] 03_Wheat_fields_furrows_and_restless_wind_5.png
# [66/300] 03_Wheat_fields_furrows_and_restless_wind_6.png
# [67/300] 03_Wheat_fields_furrows_and_restless_wind_7.png
# [68/300] 03_Wheat_fields_furrows_and_restless_wind_8.png
# [69/300] 03_Wheat_fields_furrows_and_restless_wind_9.png
# [70/300] 03_Wheat_fields_furrows_and_restless_wind_10.png
# [71/300] 03_Wheat_fields_furrows_and_restless_wind_11.png
# [72/300] 03_Wheat_fields_furrows_and_restless_wind_12.png
# [73/300] 03_Wheat_fields_furrows_and_restless_wind_13.png
# [74/300] 03_Wheat_fields_furrows_and_restless_wind_14.png
# [75/300] 03_Wheat_fields_furrows_and_restless_wind_15.png
# [76/300] 03_Wheat_fields_furrows_and_restless_wind_16.png
# [77/300] 03_Wheat_fields_furrows_and_restless_wind_17.png
# [78/300] 03_Wheat_fields_furrows_and_restless_wind_18.png
# [79/300] 03_Wheat_fields_furrows_and_restless_wind_19.png
# [80/300] 03_Wheat_fields_furrows_and_restless_wind_20.png
# [81/300] 03_Wheat_fields_furrows_and_restless_wind_21.png
# [82/300] 03_Wheat_fields_furrows_and_restless_wind_22.png
# [83/300] 03_Wheat_fields_furrows_and_restless_wind_23.png
# [84/300] 03_Wheat_fields_furrows_and_restless_wind_24.png
# [85/300] 03_Wheat_fields_furrows_and_restless_wind_25.png
# [86/300] 03_Wheat_fields_furrows_and_restless_wind_26.png
# [87/300] 03_Wheat_fields_furrows_and_restless_wind_27.png
# [88/300] 03_Wheat_fields_furrows_and_restless_wind_28.png
# [89/300] 03_Wheat_fields_furrows_and_restless_wind_29.png
# [90/300] 03_Wheat_fields_furrows_and_restless_wind_30.png
# [91/300] 04_Olive_groves_and_twisted_trunks_1.png
# [92/300] 04_Olive_groves_and_twisted_trunks_2.png
# [93/300] 04_Olive_groves_and_twisted_trunks_3.png
# [94/300] 04_Olive_groves_and_twisted_trunks_4.png
# [95/300] 04_Olive_groves_and_twisted_trunks_5.png
# [96/300] 04_Olive_groves_and_twisted_trunks_6.png
# [97/300] 04_Olive_groves_and_twisted_trunks_7.png
# [98/300] 04_Olive_groves_and_twisted_trunks_8.png
# [99/300] 04_Olive_groves_and_twisted_trunks_9.png
# [100/300] 04_Olive_groves_and_twisted_trunks_10.png
# [101/300] 04_Olive_groves_and_twisted_trunks_11.png
# [102/300] 04_Olive_groves_and_twisted_trunks_12.png
# [103/300] 04_Olive_groves_and_twisted_trunks_13.png
# [104/300] 04_Olive_groves_and_twisted_trunks_14.png
# [105/300] 04_Olive_groves_and_twisted_trunks_15.png
# [106/300] 04_Olive_groves_and_twisted_trunks_16.png
# [107/300] 04_Olive_groves_and_twisted_trunks_17.png
# [108/300] 04_Olive_groves_and_twisted_trunks_18.png
# [109/300] 04_Olive_groves_and_twisted_trunks_19.png
# [110/300] 04_Olive_groves_and_twisted_trunks_20.png
# [111/300] 04_Olive_groves_and_twisted_trunks_21.png
# [112/300] 04_Olive_groves_and_twisted_trunks_22.png
# [113/300] 04_Olive_groves_and_twisted_trunks_23.png
# [114/300] 04_Olive_groves_and_twisted_trunks_24.png
# [115/300] 04_Olive_groves_and_twisted_trunks_25.png
# [116/300] 04_Olive_groves_and_twisted_trunks_26.png
# [117/300] 04_Olive_groves_and_twisted_trunks_27.png
# [118/300] 04_Olive_groves_and_twisted_trunks_28.png
# [119/300] 04_Olive_groves_and_twisted_trunks_29.png
# [120/300] 04_Olive_groves_and_twisted_trunks_30.png
# [121/300] 05_Village_lanes_cottages_and_church_spires_1.png
# [122/300] 05_Village_lanes_cottages_and_church_spires_2.png
# [123/300] 05_Village_lanes_cottages_and_church_spires_3.png
# [124/300] 05_Village_lanes_cottages_and_church_spires_4.png
# [125/300] 05_Village_lanes_cottages_and_church_spires_5.png
# [126/300] 05_Village_lanes_cottages_and_church_spires_6.png
# [127/300] 05_Village_lanes_cottages_and_church_spires_7.png
# [128/300] 05_Village_lanes_cottages_and_church_spires_8.png
# [129/300] 05_Village_lanes_cottages_and_church_spires_9.png
# [130/300] 05_Village_lanes_cottages_and_church_spires_10.png
# [131/300] 05_Village_lanes_cottages_and_church_spires_11.png
# [132/300] 05_Village_lanes_cottages_and_church_spires_12.png
# [133/300] 05_Village_lanes_cottages_and_church_spires_13.png
# [134/300] 05_Village_lanes_cottages_and_church_spires_14.png
# [135/300] 05_Village_lanes_cottages_and_church_spires_15.png
# [136/300] 05_Village_lanes_cottages_and_church_spires_16.png
# [137/300] 05_Village_lanes_cottages_and_church_spires_17.png
# [138/300] 05_Village_lanes_cottages_and_church_spires_18.png
# [139/300] 05_Village_lanes_cottages_and_church_spires_19.png
# [140/300] 05_Village_lanes_cottages_and_church_spires_20.png
# [141/300] 05_Village_lanes_cottages_and_church_spires_21.png
# [142/300] 05_Village_lanes_cottages_and_church_spires_22.png
# [143/300] 05_Village_lanes_cottages_and_church_spires_23.png
# [144/300] 05_Village_lanes_cottages_and_church_spires_24.png
# [145/300] 05_Village_lanes_cottages_and_church_spires_25.png
# [146/300] 05_Village_lanes_cottages_and_church_spires_26.png
# [147/300] 05_Village_lanes_cottages_and_church_spires_27.png
# [148/300] 05_Village_lanes_cottages_and_church_spires_28.png
# [149/300] 05_Village_lanes_cottages_and_church_spires_29.png
# [150/300] 05_Village_lanes_cottages_and_church_spires_30.png
# [151/300] 06_Modest_bedrooms_and_domestic_interiors_1.png
# [152/300] 06_Modest_bedrooms_and_domestic_interiors_2.png
# [153/300] 06_Modest_bedrooms_and_domestic_interiors_3.png
# [154/300] 06_Modest_bedrooms_and_domestic_interiors_4.png
# [155/300] 06_Modest_bedrooms_and_domestic_interiors_5.png
# [156/300] 06_Modest_bedrooms_and_domestic_interiors_6.png
# [157/300] 06_Modest_bedrooms_and_domestic_interiors_7.png
# [158/300] 06_Modest_bedrooms_and_domestic_interiors_8.png
# [159/300] 06_Modest_bedrooms_and_domestic_interiors_9.png
# [160/300] 06_Modest_bedrooms_and_domestic_interiors_10.png
# [161/300] 06_Modest_bedrooms_and_domestic_interiors_11.png
# [162/300] 06_Modest_bedrooms_and_domestic_interiors_12.png
# [163/300] 06_Modest_bedrooms_and_domestic_interiors_13.png
# [164/300] 06_Modest_bedrooms_and_domestic_interiors_14.png
# [165/300] 06_Modest_bedrooms_and_domestic_interiors_15.png
# [166/300] 06_Modest_bedrooms_and_domestic_interiors_16.png
# [167/300] 06_Modest_bedrooms_and_domestic_interiors_17.png
# [168/300] 06_Modest_bedrooms_and_domestic_interiors_18.png
# [169/300] 06_Modest_bedrooms_and_domestic_interiors_19.png
# [170/300] 06_Modest_bedrooms_and_domestic_interiors_20.png
# [171/300] 06_Modest_bedrooms_and_domestic_interiors_21.png
# [172/300] 06_Modest_bedrooms_and_domestic_interiors_22.png
# [173/300] 06_Modest_bedrooms_and_domestic_interiors_23.png
# [174/300] 06_Modest_bedrooms_and_domestic_interiors_24.png
# [175/300] 06_Modest_bedrooms_and_domestic_interiors_25.png
# [176/300] 06_Modest_bedrooms_and_domestic_interiors_26.png
# [177/300] 06_Modest_bedrooms_and_domestic_interiors_27.png
# [178/300] 06_Modest_bedrooms_and_domestic_interiors_28.png
# [179/300] 06_Modest_bedrooms_and_domestic_interiors_29.png
# [180/300] 06_Modest_bedrooms_and_domestic_interiors_30.png
# [181/300] 07_Caf_terraces_and_lamplit_evening_streets_1.png
# [182/300] 07_Caf_terraces_and_lamplit_evening_streets_2.png
# [183/300] 07_Caf_terraces_and_lamplit_evening_streets_3.png
# [184/300] 07_Caf_terraces_and_lamplit_evening_streets_4.png
# [185/300] 07_Caf_terraces_and_lamplit_evening_streets_5.png
# [186/300] 07_Caf_terraces_and_lamplit_evening_streets_6.png
# [187/300] 07_Caf_terraces_and_lamplit_evening_streets_7.png
# [188/300] 07_Caf_terraces_and_lamplit_evening_streets_8.png
# [189/300] 07_Caf_terraces_and_lamplit_evening_streets_9.png
# [190/300] 07_Caf_terraces_and_lamplit_evening_streets_10.png
# [191/300] 07_Caf_terraces_and_lamplit_evening_streets_11.png
# [192/300] 07_Caf_terraces_and_lamplit_evening_streets_12.png
# [193/300] 07_Caf_terraces_and_lamplit_evening_streets_13.png
# [194/300] 07_Caf_terraces_and_lamplit_evening_streets_14.png
# [195/300] 07_Caf_terraces_and_lamplit_evening_streets_15.png
# [196/300] 07_Caf_terraces_and_lamplit_evening_streets_16.png
# [197/300] 07_Caf_terraces_and_lamplit_evening_streets_17.png
# [198/300] 07_Caf_terraces_and_lamplit_evening_streets_18.png
# [199/300] 07_Caf_terraces_and_lamplit_evening_streets_19.png
# [200/300] 07_Caf_terraces_and_lamplit_evening_streets_20.png
# [201/300] 07_Caf_terraces_and_lamplit_evening_streets_21.png
# [202/300] 07_Caf_terraces_and_lamplit_evening_streets_22.png
# [203/300] 07_Caf_terraces_and_lamplit_evening_streets_23.png
# [204/300] 07_Caf_terraces_and_lamplit_evening_streets_24.png
# [205/300] 07_Caf_terraces_and_lamplit_evening_streets_25.png
# [206/300] 07_Caf_terraces_and_lamplit_evening_streets_26.png
# [207/300] 07_Caf_terraces_and_lamplit_evening_streets_27.png
# [208/300] 07_Caf_terraces_and_lamplit_evening_streets_28.png
# [209/300] 07_Caf_terraces_and_lamplit_evening_streets_29.png
# [210/300] 07_Caf_terraces_and_lamplit_evening_streets_30.png
# [211/300] 08_Blossom_orchards_and_spring_gardens_1.png
# [212/300] 08_Blossom_orchards_and_spring_gardens_2.png
# [213/300] 08_Blossom_orchards_and_spring_gardens_3.png
# [214/300] 08_Blossom_orchards_and_spring_gardens_4.png
# [215/300] 08_Blossom_orchards_and_spring_gardens_5.png
# [216/300] 08_Blossom_orchards_and_spring_gardens_6.png
# [217/300] 08_Blossom_orchards_and_spring_gardens_7.png
# [218/300] 08_Blossom_orchards_and_spring_gardens_8.png
# [219/300] 08_Blossom_orchards_and_spring_gardens_9.png
# [220/300] 08_Blossom_orchards_and_spring_gardens_10.png
# [221/300] 08_Blossom_orchards_and_spring_gardens_11.png
# [222/300] 08_Blossom_orchards_and_spring_gardens_12.png
# [223/300] 08_Blossom_orchards_and_spring_gardens_13.png
# [224/300] 08_Blossom_orchards_and_spring_gardens_14.png
# [225/300] 08_Blossom_orchards_and_spring_gardens_15.png
# [226/300] 08_Blossom_orchards_and_spring_gardens_16.png
# [227/300] 08_Blossom_orchards_and_spring_gardens_17.png
# [228/300] 08_Blossom_orchards_and_spring_gardens_18.png
# [229/300] 08_Blossom_orchards_and_spring_gardens_19.png
# [230/300] 08_Blossom_orchards_and_spring_gardens_20.png
# [231/300] 08_Blossom_orchards_and_spring_gardens_21.png
# [232/300] 08_Blossom_orchards_and_spring_gardens_22.png
# [233/300] 08_Blossom_orchards_and_spring_gardens_23.png
# [234/300] 08_Blossom_orchards_and_spring_gardens_24.png
# [235/300] 08_Blossom_orchards_and_spring_gardens_25.png
# [236/300] 08_Blossom_orchards_and_spring_gardens_26.png
# [237/300] 08_Blossom_orchards_and_spring_gardens_27.png
# [238/300] 08_Blossom_orchards_and_spring_gardens_28.png
# [239/300] 08_Blossom_orchards_and_spring_gardens_29.png
# [240/300] 08_Blossom_orchards_and_spring_gardens_30.png
# [241/300] 09_Sowers_reapers_and_rural_labor_1.png
# [242/300] 09_Sowers_reapers_and_rural_labor_2.png
# [243/300] 09_Sowers_reapers_and_rural_labor_3.png
# [244/300] 09_Sowers_reapers_and_rural_labor_4.png
# [245/300] 09_Sowers_reapers_and_rural_labor_5.png
# [246/300] 09_Sowers_reapers_and_rural_labor_6.png
# [247/300] 09_Sowers_reapers_and_rural_labor_7.png
# [248/300] 09_Sowers_reapers_and_rural_labor_8.png
# [249/300] 09_Sowers_reapers_and_rural_labor_9.png
# [250/300] 09_Sowers_reapers_and_rural_labor_10.png
# [251/300] 09_Sowers_reapers_and_rural_labor_11.png
# [252/300] 09_Sowers_reapers_and_rural_labor_12.png
# [253/300] 09_Sowers_reapers_and_rural_labor_13.png
# [254/300] 09_Sowers_reapers_and_rural_labor_14.png
# [255/300] 09_Sowers_reapers_and_rural_labor_15.png
# [256/300] 09_Sowers_reapers_and_rural_labor_16.png
# [257/300] 09_Sowers_reapers_and_rural_labor_17.png
# [258/300] 09_Sowers_reapers_and_rural_labor_18.png
# [259/300] 09_Sowers_reapers_and_rural_labor_19.png
# [260/300] 09_Sowers_reapers_and_rural_labor_20.png
# [261/300] 09_Sowers_reapers_and_rural_labor_21.png
# [262/300] 09_Sowers_reapers_and_rural_labor_22.png
# [263/300] 09_Sowers_reapers_and_rural_labor_23.png
# [264/300] 09_Sowers_reapers_and_rural_labor_24.png
# [265/300] 09_Sowers_reapers_and_rural_labor_25.png
# [266/300] 09_Sowers_reapers_and_rural_labor_26.png
# [267/300] 09_Sowers_reapers_and_rural_labor_27.png
# [268/300] 09_Sowers_reapers_and_rural_labor_28.png
# [269/300] 09_Sowers_reapers_and_rural_labor_29.png
# [270/300] 09_Sowers_reapers_and_rural_labor_30.png
# [271/300] 10_Rivers_bridges_and_moored_boats_1.png
# [272/300] 10_Rivers_bridges_and_moored_boats_2.png
# [273/300] 10_Rivers_bridges_and_moored_boats_3.png
# [274/300] 10_Rivers_bridges_and_moored_boats_4.png
# [275/300] 10_Rivers_bridges_and_moored_boats_5.png
# [276/300] 10_Rivers_bridges_and_moored_boats_6.png
# [277/300] 10_Rivers_bridges_and_moored_boats_7.png
# [278/300] 10_Rivers_bridges_and_moored_boats_8.png
# [279/300] 10_Rivers_bridges_and_moored_boats_9.png
# [280/300] 10_Rivers_bridges_and_moored_boats_10.png
# [281/300] 10_Rivers_bridges_and_moored_boats_11.png
# [282/300] 10_Rivers_bridges_and_moored_boats_12.png
# [283/300] 10_Rivers_bridges_and_moored_boats_13.png
# [284/300] 10_Rivers_bridges_and_moored_boats_14.png
# [285/300] 10_Rivers_bridges_and_moored_boats_15.png
# [286/300] 10_Rivers_bridges_and_moored_boats_16.png
# [287/300] 10_Rivers_bridges_and_moored_boats_17.png
# [288/300] 10_Rivers_bridges_and_moored_boats_18.png
# [289/300] 10_Rivers_bridges_and_moored_boats_19.png
# [290/300] 10_Rivers_bridges_and_moored_boats_20.png
# [291/300] 10_Rivers_bridges_and_moored_boats_21.png
# [292/300] 10_Rivers_bridges_and_moored_boats_22.png
# [293/300] 10_Rivers_bridges_and_moored_boats_23.png
# [294/300] 10_Rivers_bridges_and_moored_boats_24.png
# [295/300] 10_Rivers_bridges_and_moored_boats_25.png
# [296/300] 10_Rivers_bridges_and_moored_boats_26.png
# [297/300] 10_Rivers_bridges_and_moored_boats_27.png
# [298/300] 10_Rivers_bridges_and_moored_boats_28.png
# [299/300] 10_Rivers_bridges_and_moored_boats_29.png
# [300/300] 10_Rivers_bridges_and_moored_boats_30.png

# %%
# Save a manifest
manifest_path = out_dir / "manifest.csv"
pd.DataFrame(records).to_csv(manifest_path, index=False)

# %%
# Convert manifest.csv -> metadata.jsonl
import json

metadata_path = out_dir / "metadata.jsonl"

with open(metadata_path, "w", encoding="utf-8") as f:
    for _, row in pd.read_csv(manifest_path).iterrows():
        f.write(json.dumps({
            "file_name": Path(row["image_path"]).name,
            "text": row["prompt"],
        }, ensure_ascii=False) + "\n")
